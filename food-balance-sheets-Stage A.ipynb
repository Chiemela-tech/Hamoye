# %% [markdown]
# <a href="https://www.kaggle.com/code/chiemelachinedum/food-balance-sheets?scriptVersionId=131457441" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/food-data/FoodBalanceSheets_E_Africa_NOFLAG.csv

# %%
# import pandas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the csv file into a variable heart_data
food_data = pd.read_csv("/kaggle/input/food-data/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin-1")

# %%
display(food_data)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# # Question 1
# # Which of these python data structures is unorderly?
# Dictionary
# List
# Tuple
# Set
#
# Answer is Set

# %% [markdown]
# # Question 2
# # What is the total Protein supply quantity in Madagascar in 2015?

# %%
food_data_madag = food_data.loc[(food_data.Area == 'Madagascar') & (food_data.Element == 'Protein supply quantity (g/capita/day)')]
food_data_madag['Y2015'].sum()
# Out:
# 173.04999999999998

# %% [markdown]
# * The total Protein supply quantity in Madagascar in 2015 is 173.05

# %% [markdown]
# # Question 3
# # Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?

# %%
food_data.groupby(['Area'], sort=True)['Y2017'].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %% [markdown]
# * Capo Verde has the 7th lowest sum in 2017

# %% [markdown]
# # Question 4
# # What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?

# %%
food_data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %% [markdown]
# * The mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places are 140.92 and 1671.86

# %% [markdown]
# # Question 5
# # Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?

# %%
food_data.groupby(['Element']).sum()
# Out:
# /tmp/ipykernel_20/1641616304.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   food_data.groupby(['Element']).sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...

# %% [markdown]
# * The total number of sum of processing in 2017 is 292836.00

# %% [markdown]
# # Question 6
#  # Which of the following dataframe methods can be used to access elements across rows and columns?
# df.loc( )
# df.iloc( )
# df.loc( : )
# df.iloc[ : ]
# c and d
#
# The answer is df.loc()

# %% [markdown]
# # Question 7
# # What would be the output for?
# S = [['him', 'sell'], [90, 28, 43]]
# S[0][1][1]

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %% [markdown]
# * The answer is 'e'

# %% [markdown]
# # Question 8
# # Which year had the least correlation with ‘Element Code’?

# %%
food_data.corr()
# Out:
# /tmp/ipykernel_20/3472151187.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   food_data.corr()
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# ...

# %% [markdown]
# * The year 2016 had the least correlation with 'Element Code'

# %% [markdown]
# # Question 9
# # Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?

# %%
food_data.groupby(['Element']).sum()
# Out:
# /tmp/ipykernel_20/1641616304.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   food_data.groupby(['Element']).sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...

# %% [markdown]
# * 2014 has the highest sum of Stock Variation

# %% [markdown]
# # Question 10
# # How would you check for the number of rows and columns in a pandas DataFrame named df?
#  len(df)
# df.shape( )
# pd.length(df)
# df.shape
#
# The answer is df.shape()

# %% [markdown]
# # Question 11
# # Which of the following is a python inbuilt module?
# Math
# Pandas
# Matplotlib
# Seaborn
#
# The answer is Math

# %% [markdown]
# # Question 12
# # Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the highest sum in 2017?

# %%
food_data.groupby(['Y2017', 'Area']).sum()
# Out:
# /tmp/ipykernel_20/363971789.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   food_data.groupby(['Y2017', 'Area']).sum()
#                                        Area Code  Item Code  Element Code  \
# Y2017     Area
# -1582.0   Egypt                              118       5445         10144
# -1200.0   Mozambique                         144       2532          5072
# -1159.0   Mozambique                         144       2907          5072
# -865.0    United Republic of Tanzania        215       2913          5072
# -860.0    United Republic of Tanzania        215       2556          5072
# ...                                          ...        ...           ...
#  96443.0  Egypt                               59       2501           511
# ...

# %% [markdown]
# * Nigeria has the highest sum in 2017

# %% [markdown]
# # Question 13
# # Given the following python code, what would the output of the code give?
# my_tuppy = (1,2,5,8)
# my_tuppy[2] = 6
# Type Error
# Value Error
# Standard Error
# Math Error

# %% [markdown]
# * It produces a Type error

# %% [markdown]
# # Question 14
# # A pandas Dataframe with dimensions (100,3) has how many features and observations?
# 100 rows and 3 observations.
# A pandas dataframe has no attribute feature or observation.
# 3 features, 100 observations
# 100 features, 3 observations.

# %% [markdown]
# * It represents 100 rows and 3 observations

# %% [markdown]
# # Question 15
# # If you have the following list
# lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
# col = [‘Age’,’Nationality’,’Overall’]
# How do you create a pandas DataFrame using this list, to look like the table below?

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age', 'Nationality', 'Overall']

pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %% [markdown]
# * This is the answer
# pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])

# %% [markdown]
# # Question 16
# # Answer the following questions based on the African food production dataset provided by the FAO website already provided
# # What is the total sum of Wine produced in 2015 and 2018 respectively?
# Hint:
# Perform a groupby sum aggregation on ‘Item’

# %%
food_data.groupby(['Item']).sum()
# Out:
# /tmp/ipykernel_20/3251484073.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   food_data.groupby(['Item']).sum()
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# ...

# %% [markdown]
# * Total sum of wine produced in 2015 and 2018 are 4251.81 and 4039.32 respectively

# %% [markdown]
# # Question 18
# # What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
food_data.isna().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %% [markdown]
# * There are 1589 and 2.607% of missing data in 2014

# %% [markdown]
# # Question 20
# # What is the total number of unique countries in the dataset?

# %%
food_data['Area'].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %% [markdown]
# * There are 50 countries in the dataset
